# %%
# nov 28th (500)
daily_csv_path = "/Workspace/Users/ssriniva661@gmail.com/Daily_AQI_ETL_Analytics_Pipeline/files/aqi/delta/daily/*.csv"
df = spark.read.csv(daily_csv_path, header=True, inferSchema=True)
df.createOrReplaceTempView("aqi_all_days")

# %%
# %sql
SELECT COUNT(*) as daily_count
FROM aqi_all_days;
